# %% [markdown]
# # Day 7 – Data Analysis
#
# ## Objective
#
# The objective of this task is to perform basic data analysis using Pandas by calculating totals, averages, minimum values, maximum values, and counts.

# %%
import pandas as pd

# %%
df = pd.read_csv("Cleaned_Dataset_Day10.csv")

# %%
df.head()
# Out:
#      OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000  2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001  2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002  2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003  2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004  2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
df["TotalPrice"].sum()
# Out:
# np.float64(1264761.96)

# %%
df["TotalPrice"].mean()
# Out:
# np.float64(1053.9683)

# %%
df["TotalPrice"].min()
# Out:
# np.float64(11.39)

# %%
df["TotalPrice"].max()
# Out:
# np.float64(3456.4)

# %%
df["TotalPrice"].count()
# Out:
# np.int64(1200)

# %%
df["TotalPrice"].agg(["sum", "mean", "min", "max", "count"])
# Out:
# sum      1.264762e+06
# mean     1.053968e+03
# min      1.139000e+01
# max      3.456400e+03
# count    1.200000e+03
# Name: TotalPrice, dtype: float64

# %% [markdown]
# # Day 7 Summary
#
# In this task, I performed basic data analysis using Pandas. I calculated the total, average, minimum, maximum, and count of the TotalPrice column.
#
# These calculations provided a basic understanding of the values in the dataset and prepared the data for visualization in Day 8.
